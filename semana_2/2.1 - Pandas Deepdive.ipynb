# %% [markdown]
# # 2.1 - Pandas Deepdive
#
# ![pandas_deep](images/pandas_deep.jpg)

# %% [markdown]
# ### Importar un archivo

# %%
import pandas as pd
import numpy as np

# %%
# desde un zip

import zipfile

zf=zipfile.ZipFile('../data/mahindra.zip')

ctr=pd.read_csv(zf.open('test.csv'), nrows=1e5)

ctr.head()
# Out:
#                                       reservation_id booking_date  \
# 0  7dae1ce6bc8f69481328f2be5c4943077dad5598b5f66d...     05/04/18
# 1  fe0d4e444e1818436c88f72f1cf800536c2f785e59baeb...     24/05/15
# 2  540bd4285ad8168e8388f84ee74a82cd4f97dc0a404d3e...     21/07/15
# 3  09593c907ae262e46f655b4db9e14f54a19eadcfdd2679...     31/07/15
# 4  f4c50caac68051faf37551d70bb17eebef2a20e2244cb1...     01/07/16
#
#   checkin_date checkout_date  channel_code  main_product_code  numberofadults  \
# 0     05/04/18      06/04/18             3                  2               2
# 1     23/06/15      27/06/15             1                  2               4
# 2     07/08/15      10/08/15             3                  2               3
# 3     22/10/15      25/10/15             1                  2               3
# 4     01/10/16      05/10/16             1                  2               4
#
#    numberofchildren  persontravellingid  resort_region_code  ...  \
# 0                 0                  45                   3  ...
# 1                 0                  45                   1  ...
# 2                 0                  45                   2  ...
# 3                 0                  45                   1  ...
# 4                 0                  45                   1  ...
#
#    season_holidayed_code  state_code_residence  state_code_resort  total_pax  \
# 0                    2.0                   2.0                  3          3
# 1                    2.0                   2.0                  4          2
# 2                    4.0                   2.0                  2          3
# 3                    2.0                   2.0                  6          3
# 4                    2.0                   2.0                 11          2
#
#    member_age_buckets  booking_type_code  \
# 0                   H                  1
# 1                   H                  1
# 2                   H                  1
# 3                   H                  1
# 4                   H                  1
#
#                                             memberid cluster_code  \
# 0  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            A
# 1  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            F
# 2  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            D
# 3  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            F
# 4  2114944930dcc42ce5b9b50ae965cf8a9c04e46be63d84...            F
#
#    reservationstatusid_code                                          resort_id
# 0                         C  9f14025af0065b30e47e23ebb3b491d39ae8ed17d33739...
# 1                         A  e7f6c011776e8db7cd330b54174fd76f7d0216b612387a...
# 2                         A  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3                         A  49d180ecf56132819571bf39d9b7b342522a2ac6d23c14...
# 4                         A  e29c9c180c6279b0b02abd6a1801c7c04082cf486ec027...
#
# [5 rows x 23 columns]

# %%
df=pd.read_excel('../data/Online Retail.xlsx')

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
# crear una columna de nulos

df['Null ID']=[i if i%2 else None for i in range(len(df))]

df.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country  Null ID
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN

# %%
# renombrar columnas

df.columns
# Out:
# Index(['InvoiceNo', 'InvoiceDate', 'StockCode', 'Description', 'Quantity',
#        'UnitPrice', 'Revenue', 'CustomerID', 'Country', 'Null ID'],
#       dtype='object')

# %%
df.columns=[c.lower().replace(' ', '_') for c in df.columns]

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN

# %%
n_cols=[c.lower().replace(' ', '_') for c in df.columns]

# %%
df=df.rename(columns={k:v for k,v in zip(df.columns, n_cols)})    # k=vieja columna, v=nueva columna

df.head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN

# %% [markdown]
# ### Descripción de los datos

# %%
df.shape
# Out:
# (396034, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null_id      198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 30.2+ MB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null_id      198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 93.7 MB

# %%
df2=df.copy()

# %%
df.count()  # valores no nulos
# Out:
# invoiceno      396034
# invoicedate    396034
# stockcode      396034
# description    396034
# quantity       396034
# unitprice      396034
# revenue        396034
# customerid     396034
# country        396034
# null_id        198017
# dtype: int64

# %%
df.country.unique()   # cuenta valores unicos de la columna
# Out:
# array(['United Kingdom', 'Spain', 'Cyprus', 'EIRE', 'Portugal',
#        'Netherlands', 'Australia', 'Singapore', 'Switzerland', 'Finland',
#        'Channel Islands', 'France', 'Malta', 'Italy', 'Israel', 'Germany',
#        'Austria', 'Norway', 'Denmark', 'Sweden', 'Belgium', 'Canada',
#        'Poland', 'Japan', 'Iceland', 'Greece', 'Lebanon', 'South Africa',
#        'Czech Republic', 'USA', 'Brazil', 'United Arab Emirates',
#        'Lithuania', 'Saudi Arabia', 'Bahrain'], dtype=object)

# %%
df.country.value_counts()  # cuenta de valores unicos dentro de la columna
# Out:
# United Kingdom          353983
# Germany                   8658
# France                    8034
# EIRE                      7136
# Spain                     2422
# Netherlands               2322
# Belgium                   1935
# Switzerland               1810
# Portugal                  1425
# Australia                 1181
# Norway                    1048
# Channel Islands            744
# Italy                      741
# Finland                    647
# Cyprus                     612
# Sweden                     428
# Austria                    384
# Denmark                    367
# Poland                     325
# Japan                      321
# Israel                     248
# Singapore                  215
# Iceland                    182
# USA                        179
# Canada                     150
# Greece                     142
# Malta                      109
# United Arab Emirates        67
# South Africa                57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              24
# Bahrain                     17
# Saudi Arabia                 9
# Name: country, dtype: int64

# %%
# descripcion estadistica

df.describe()
# Out:
#            invoiceno       quantity      unitprice        revenue  \
# count  396034.000000  396034.000000  396034.000000  396034.000000
# mean   560620.294401      12.624838       2.867826      21.492062
# std     13110.655964      42.816911       4.265226      93.863439
# min    536365.000000       1.000000       0.040000       0.060000
# 25%    549198.500000       2.000000       1.250000       4.680000
# 50%    561894.000000       6.000000       1.950000      11.800000
# 75%    572095.000000      12.000000       3.750000      19.800000
# max    581587.000000    4800.000000     649.500000   38970.000000
#
#           customerid        null_id
# count  396034.000000  198017.000000
# mean    15302.695435  198017.000000
# std      1709.744925  114325.456929
# min     12347.000000       1.000000
# 25%     13975.000000   99009.000000
# 50%     15160.000000  198017.000000
# 75%     16805.000000  297025.000000
# max     18287.000000  396033.000000

# %%
df.describe().T
# Out:
#                count           mean            std        min        25%  \
# invoiceno   396034.0  560620.294401   13110.655964  536365.00  549198.50
# quantity    396034.0      12.624838      42.816911       1.00       2.00
# unitprice   396034.0       2.867826       4.265226       0.04       1.25
# revenue     396034.0      21.492062      93.863439       0.06       4.68
# customerid  396034.0   15302.695435    1709.744925   12347.00   13975.00
# null_id     198017.0  198017.000000  114325.456929       1.00   99009.00
#
#                   50%        75%       max
# invoiceno   561894.00  572095.00  581587.0
# quantity         6.00      12.00    4800.0
# unitprice        1.95       3.75     649.5
# revenue         11.80      19.80   38970.0
# customerid   15160.00   16805.00   18287.0
# null_id     198017.00  297025.00  396033.0

# %%
df[['quantity', 'unitprice', 'revenue']].describe().T['50%']  # medianas por columnas
# Out:
# quantity      6.00
# unitprice     1.95
# revenue      11.80
# Name: 50%, dtype: float64

# %% [markdown]
# ### Selección dentro del dataframe

# %%
df[['quantity', 'unitprice', 'revenue']].head(3)   # seleccion por nombre de columna
# Out:
#    quantity  unitprice  revenue
# 0         6       2.55     15.3
# 1         6       2.55     15.3
# 2         6       2.55     15.3

# %%
df[df.quantity==6.].head()    # seleccion segun condicion
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A
# 8     536502 2010-12-01 12:36:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 8  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 5       17850  United Kingdom      5.0
# 8       16552  United Kingdom      NaN

# %%
df[~(df.quantity==6.)].head()  # ~es el NO logico, lo que no es 6
# Out:
#    invoiceno         invoicedate stockcode  \
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
# 6     536401 2010-12-01 11:21:00    85123A
# 7     536406 2010-12-01 11:33:00    85123A
# 9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55    81.60
# 6  CREAM HANGING HEART T-LIGHT HOLDER         4       2.95    11.80
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  null_id
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN
# 6       15862  United Kingdom      NaN
# 7       17850  United Kingdom      7.0
# 9       14729  United Kingdom      9.0

# %%
df[(df.quantity==6.) & (df.unitprice==2.55)].head()   # multicondicion, & es el Y logico
# Out:
#     invoiceno         invoicedate stockcode  \
# 0      536365 2010-12-01 08:26:00    85123A
# 1      536373 2010-12-01 09:02:00    85123A
# 2      536375 2010-12-01 09:32:00    85123A
# 5      536396 2010-12-01 10:51:00    85123A
# 15     536600 2010-12-02 08:32:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 0   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 5   CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 15  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
#
#     customerid         country  null_id
# 0        17850  United Kingdom      NaN
# 1        17850  United Kingdom      1.0
# 2        17850  United Kingdom      NaN
# 5        17850  United Kingdom      5.0
# 15       17850  United Kingdom     15.0

# %%
df[(df.quantity==6.) & ~(df.unitprice==2.55)].head()
# Out:
#     invoiceno         invoicedate stockcode  \
# 8      536502 2010-12-01 12:36:00    85123A
# 13     536590 2010-12-01 16:52:00    85123A
# 14     536594 2010-12-01 17:22:00    85123A
# 17     536607 2010-12-02 09:29:00    85123A
# 32     536833 2010-12-02 17:48:00    85123A
#
#                            description  quantity  unitprice  revenue  \
# 8   CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 13  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 14  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 17  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 32  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#     customerid         country  null_id
# 8        16552  United Kingdom      NaN
# 13       13065  United Kingdom     13.0
# 14       15235  United Kingdom      NaN
# 17       17732  United Kingdom     17.0
# 32       18239  United Kingdom      NaN

# %%
df[(df.quantity==6) | (df.country=='EIRE')].head()   # multicondicion, | es el O (or) logico
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A
# 8     536502 2010-12-01 12:36:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 8  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 5       17850  United Kingdom      5.0
# 8       16552  United Kingdom      NaN

# %%
df[(df.quantity==6) | (df.country=='EIRE')][['quantity', 'unitprice', 'revenue']].head()
# Out:
#    quantity  unitprice  revenue
# 0         6       2.55     15.3
# 1         6       2.55     15.3
# 2         6       2.55     15.3
# 5         6       2.55     15.3
# 8         6       2.95     17.7

# %%
df.iloc[0]    # seleccion por indice
# Out:
# invoiceno                                  536365
# invoicedate                   2010-12-01 08:26:00
# stockcode                                  85123A
# description    CREAM HANGING HEART T-LIGHT HOLDER
# quantity                                        6
# unitprice                                    2.55
# revenue                                      15.3
# customerid                                  17850
# country                            United Kingdom
# null_id                                       NaN
# Name: 0, dtype: object

# %%
df.iloc[:2]
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0

# %%
df.iloc[0:2, 1:4]     # df.iloc[fila_inicial: fila_final, columna_inicial: columna_final] por indice
# Out:
#           invoicedate stockcode                         description
# 0 2010-12-01 08:26:00    85123A  CREAM HANGING HEART T-LIGHT HOLDER
# 1 2010-12-01 09:02:00    85123A  CREAM HANGING HEART T-LIGHT HOLDER

# %%
df.loc[0:3]   # localiza por elemento (nombre), es como iloc si el index y las columnas son numericas
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0

# %%
df.loc[0:2, 'quantity': 'revenue']
# Out:
#    quantity  unitprice  revenue
# 0         6       2.55     15.3
# 1         6       2.55     15.3
# 2         6       2.55     15.3

# %%
df.loc[:2, ['quantity', 'unitprice', 'revenue']]
# Out:
#    quantity  unitprice  revenue
# 0         6       2.55     15.3
# 1         6       2.55     15.3
# 2         6       2.55     15.3

# %%
df.index=[str(i) for i in range(len(df))]

df.index[0]
# Out:
# '0'

# %%
df.iloc[0:2, :4]
# Out:
#    invoiceno         invoicedate stockcode                         description
# 0     536365 2010-12-01 08:26:00    85123A  CREAM HANGING HEART T-LIGHT HOLDER
# 1     536373 2010-12-01 09:02:00    85123A  CREAM HANGING HEART T-LIGHT HOLDER

# %%
df.loc['0':'2', 'quantity': 'revenue']\
  .iloc[:1]
# Out:
#    quantity  unitprice  revenue
# 0         6       2.55     15.3

# %%
df.reset_index().head()
# Out:
#   index  invoiceno         invoicedate stockcode  \
# 0     0     536365 2010-12-01 08:26:00    85123A
# 1     1     536373 2010-12-01 09:02:00    85123A
# 2     2     536375 2010-12-01 09:32:00    85123A
# 3     3     536390 2010-12-01 10:19:00    85123A
# 4     4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.sample(5)   # muestra aleatoria de 5 filas
# Out:
#         invoiceno         invoicedate stockcode  \
# 24412      553869 2011-05-19 14:27:00     22386
# 296528     539307 2010-12-16 17:43:00    90210C
# 231485     546788 2011-03-17 10:02:00     21948
# 95855      579545 2011-11-30 10:18:00     20914
# 123601     569671 2011-10-05 13:54:00     22367
#
#                                 description  quantity  unitprice  revenue  \
# 24412               JUMBO BAG PINK POLKADOT        10       2.08     20.8
# 296528         RED   ACRYLIC FACETED BANGLE        60       1.25     75.0
# 231485             SET OF 6 CAKE CHOPSTICKS        36       1.25     45.0
# 95855   SET/5 RED RETROSPOT LID GLASS BOWLS        32       2.55     81.6
# 123601      CHILDRENS APRON SPACEBOY DESIGN         8       1.95     15.6
#
#         customerid         country   null_id
# 24412        15394  United Kingdom       NaN
# 296528       13694  United Kingdom       NaN
# 231485       13946  United Kingdom  231485.0
# 95855        13098  United Kingdom   95855.0
# 123601       16020  United Kingdom  123601.0

# %%
df.sample(frac=0.1).head()   # muestra aleatoria del 10% de los datos
# Out:
#         invoiceno         invoicedate stockcode  \
# 52356      552572 2011-05-10 12:11:00    85099B
# 209092     573166 2011-10-28 09:15:00     22460
# 126461     569653 2011-10-05 12:52:00     22551
# 382496     567304 2011-09-19 13:27:00     23398
# 265081     569866 2011-10-06 14:50:00    84536B
#
#                            description  quantity  unitprice  revenue  \
# 52356          JUMBO BAG RED RETROSPOT       200       1.79   358.00
# 209092  EMBOSSED GLASS TEALIGHT HOLDER        12       1.25    15.00
# 126461        PLASTERS IN TIN SPACEBOY        12       1.65    19.80
# 382496           HANGING HEART BONHEUR         2       0.85     1.70
# 265081    FAIRY CAKES NOTEBOOK A7 SIZE         2       0.42     0.84
#
#         customerid         country   null_id
# 52356        14680  United Kingdom       NaN
# 209092       13089  United Kingdom       NaN
# 126461       12451     Switzerland  126461.0
# 382496       14704  United Kingdom       NaN
# 265081       12757        Portugal  265081.0

# %%
df._get_numeric_data().head()  # seleccion de los datos numericos
# Out:
#    invoiceno  quantity  unitprice  revenue  customerid  null_id
# 0     536365         6       2.55     15.3       17850      NaN
# 1     536373         6       2.55     15.3       17850      1.0
# 2     536375         6       2.55     15.3       17850      NaN
# 3     536390        64       2.55    163.2       17511      3.0
# 4     536394        32       2.55     81.6       13408      NaN

# %%
df.select_dtypes(include=['float64', 'bool'], exclude='object').head()  # selccion segun el tipo de dato
# Out:
#    unitprice  revenue  null_id
# 0       2.55     15.3      NaN
# 1       2.55     15.3      1.0
# 2       2.55     15.3      NaN
# 3       2.55    163.2      3.0
# 4       2.55     81.6      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int64
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null_id      198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 30.2+ MB

# %% [markdown]
# ### Cambio del tipo de datos

# %%
df.quantity.astype(dtype='int8').head()
# Out:
# 0     6
# 1     6
# 2     6
# 3    64
# 4    32
# Name: quantity, dtype: int8

# %%
df.quantity=df.quantity.astype(dtype='int8')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int8
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null_id      198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), int8(1), object(3)
# memory usage: 27.6+ MB

# %%
df.describe()
# Out:
#            invoiceno       quantity      unitprice        revenue  \
# count  396034.000000  396034.000000  396034.000000  396034.000000
# mean   560620.294401       9.259632       2.867826      21.492062
# std     13110.655964      16.960865       4.265226      93.863439
# min    536365.000000    -128.000000       0.040000       0.060000
# 25%    549198.500000       2.000000       1.250000       4.680000
# 50%    561894.000000       5.000000       1.950000      11.800000
# 75%    572095.000000      12.000000       3.750000      19.800000
# max    581587.000000     126.000000     649.500000   38970.000000
#
#           customerid        null_id
# count  396034.000000  198017.000000
# mean    15302.695435  198017.000000
# std      1709.744925  114325.456929
# min     12347.000000       1.000000
# 25%     13975.000000   99009.000000
# 50%     15160.000000  198017.000000
# 75%     16805.000000  297025.000000
# max     18287.000000  396033.000000

# %% [markdown]
# ### Manejo de valores nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    396034 non-null  int64
#  1   invoicedate  396034 non-null  datetime64[ns]
#  2   stockcode    396034 non-null  object
#  3   description  396034 non-null  object
#  4   quantity     396034 non-null  int8
#  5   unitprice    396034 non-null  float64
#  6   revenue      396034 non-null  float64
#  7   customerid   396034 non-null  int64
#  8   country      396034 non-null  object
#  9   null_id      198017 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), int8(1), object(3)
# memory usage: 27.6+ MB

# %%
df.isna().head()    # nulos
# Out:
#    invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0      False        False      False        False     False      False
# 1      False        False      False        False     False      False
# 2      False        False      False        False     False      False
# 3      False        False      False        False     False      False
# 4      False        False      False        False     False      False
#
#    revenue  customerid  country  null_id
# 0    False       False    False     True
# 1    False       False    False    False
# 2    False       False    False     True
# 3    False       False    False    False
# 4    False       False    False     True

# %%
df.notna().head()    # NO nulos
# Out:
#    invoiceno  invoicedate  stockcode  description  quantity  unitprice  \
# 0       True         True       True         True      True       True
# 1       True         True       True         True      True       True
# 2       True         True       True         True      True       True
# 3       True         True       True         True      True       True
# 4       True         True       True         True      True       True
#
#    revenue  customerid  country  null_id
# 0     True        True     True    False
# 1     True        True     True     True
# 2     True        True     True    False
# 3     True        True     True     True
# 4     True        True     True    False

# %%
nan_cols=df.isna().sum()  # columnas con nulos

nan_cols[nan_cols>0]
# Out:
# null_id    198017
# dtype: int64

# %% [markdown]
# **¿Qué hacemos?**

# %%
# podemos rellenar

df.fillna(0).head()    # con un elemento
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null_id
# 0       17850  United Kingdom      0.0
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      0.0
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      0.0

# %%
df.fillna(df.null_id.mean()).head()    # con la media
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country   null_id
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %%
df.fillna(df.null_id.median()).head()    # con la mediana
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country   null_id
# 0       17850  United Kingdom  198017.0
# 1       17850  United Kingdom       1.0
# 2       17850  United Kingdom  198017.0
# 3       17511  United Kingdom       3.0
# 4       13408  United Kingdom  198017.0

# %%
df.null_id.median()
# Out:
# 198017.0

# %%
# podemos borrar la columna

df.drop('null_id', axis=1).head()   # una columna
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
df.drop(columns=['revenue', 'customerid', 'country']).head()   # mas de una columna
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  null_id
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55      NaN
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55      1.0
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55      NaN
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55      3.0
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55      NaN

# %%
# podemos borrar registros, filas

df[df.null_id.notna()].head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 1     536373 2010-12-01 09:02:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A
# 7     536406 2010-12-01 11:33:00    85123A
# 9     536520 2010-12-01 12:43:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    customerid         country  null_id
# 1       17850  United Kingdom      1.0
# 3       17511  United Kingdom      3.0
# 5       17850  United Kingdom      5.0
# 7       17850  United Kingdom      7.0
# 9       14729  United Kingdom      9.0

# %%
# borra todo lo nulo

df.dropna(axis=1).head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
# eliminar duplicados

df.drop_duplicates().head()
# Out:
#    invoiceno         invoicedate stockcode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           description  quantity  unitprice  revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    customerid         country  null_id
# 0       17850  United Kingdom      NaN
# 1       17850  United Kingdom      1.0
# 2       17850  United Kingdom      NaN
# 3       17511  United Kingdom      3.0
# 4       13408  United Kingdom      NaN

# %%
df.drop_duplicates(subset=['country', 'unitprice']).head()  # en una columna especifica
# Out:
#      invoiceno         invoicedate stockcode  \
# 0       536365 2010-12-01 08:26:00    85123A
# 6       536401 2010-12-01 11:21:00    85123A
# 103     538095 2010-12-09 14:55:00    85123A
# 147     538826 2010-12-14 12:58:00    85123A
# 179     539320 2010-12-16 19:16:00    85123A
#
#                             description  quantity  unitprice  revenue  \
# 0    CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 6    CREAM HANGING HEART T-LIGHT HOLDER         4       2.95    11.80
# 103  CREAM HANGING HEART T-LIGHT HOLDER         1       2.95     2.95
# 147  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 179  CREAM HANGING HEART T-LIGHT HOLDER        24       2.95    70.80
#
#      customerid         country  null_id
# 0         17850  United Kingdom      NaN
# 6         15862  United Kingdom      NaN
# 103       17097           Spain    103.0
# 147       12370          Cyprus    147.0
# 179       14911            EIRE    179.0

# %% [markdown]
# ### Agrupación

# %%
df.groupby('country').sum().head()            # para agrupar siempre es necesara una funcion de agregacion
# Out:
#             invoiceno  quantity  unitprice    revenue  customerid      null_id
# country
# Australia   656866967   21692.0    3262.50  138171.31    14708852  116591145.0
# Austria     216042887    3820.0    1145.90    8742.68     4808382   36538436.0
# Bahrain       9397437     260.0      78.95     548.40      210027    1300214.0
# Belgium    1084768176   22194.0    5887.85   36927.34    24054214  193310168.0
# Brazil       17606432     356.0     142.60    1143.60      408608    2712644.0

# %%
df.groupby('country').agg({'quantity': 'sum', 'revenue': 'mean'}).head()
# Out:
#            quantity     revenue
# country
# Australia   21692.0  116.995182
# Austria      3820.0   22.767396
# Bahrain       260.0   32.258824
# Belgium     22194.0   19.083897
# Brazil        356.0   35.737500

# %%
def suma(x):
    '''recibe una serie y devuelve un numero'''
    return sum(x+2)

# %%
df.groupby('country').agg({'quantity': suma}).head()  # funcion custom
# Out:
#            quantity
# country
# Australia     24054
# Austria        4588
# Bahrain         294
# Belgium       26064
# Brazil          420

# %%
df.groupby('country').agg({'unitprice': ['mean', 'median', 'std']}).head()  # varias funciones
# Out:
#           unitprice
#                mean median       std
# country
# Australia  2.762489   1.79  2.424046
# Austria    2.984115   1.95  3.161760
# Bahrain    4.644118   2.95  3.673634
# Belgium    3.042817   1.95  3.402533
# Brazil     4.456250   3.32  2.831727

# %%
df.groupby('country').agg(['mean', 'median', 'std']).head()
# Out:
# /var/folders/fv/zc4lh9sn7bnf55fy6jhl0k900000gn/T/ipykernel_63458/840971281.py:1: FutureWarning: ['invoicedate', 'stockcode', 'description'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('country').agg(['mean', 'median', 'std']).head()
#                invoiceno                           quantity                    \
#                     mean    median           std       mean median        std
# country
# Australia  556195.569009  556917.0  10347.568409  18.367485   12.0  55.149954
# Austria    562611.684896  562602.0  10375.962626   9.947917   10.0  11.552464
# Bahrain    552790.411765  552449.0    634.431346  15.294118    6.0  24.959379
# Belgium    560603.708527  561507.0  11977.330901  11.469767   10.0  11.967942
# Brazil     550201.000000  550201.0      0.000000  11.125000   10.0   8.476723
#
#           unitprice                      revenue                     \
#                mean median       std        mean median         std
# country
# Australia  2.762489   1.79  2.424046  116.995182  66.00  159.820336
# Austria    2.984115   1.95  3.161760   22.767396  17.00   27.401579
# Bahrain    4.644118   2.95  3.673634   32.258824  25.50   26.878478
# Belgium    3.042817   1.95  3.402533   19.083897  16.60   13.235034
# Brazil     4.456250   3.32  2.831727   35.737500  19.65   32.896282
#
#              customerid                             null_id            \
#                    mean   median         std           mean    median
# country
# Australia  12454.574090  12415.0  392.096266  204905.351494  213031.0
# Austria    12521.828125  12374.0  217.057432  192307.557895  198362.0
# Bahrain    12354.529412  12355.0    0.874475  216702.333333  216515.0
# Belgium    12431.118346  12407.0  111.880194  199700.586777  206364.0
# Brazil     12769.000000  12769.0    0.000000  193760.285714  187979.0
#
#
#                      std
# country
# Australia  119222.565962
# Austria    114040.947192
# Bahrain     66964.683464
# Belgium    116219.245415
# Brazil     115305.958108

# %%
df.groupby('country').agg(['mean', 'median', 'std']).columns
# Out:
# /var/folders/fv/zc4lh9sn7bnf55fy6jhl0k900000gn/T/ipykernel_63458/2947103428.py:1: FutureWarning: ['invoicedate', 'stockcode', 'description'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('country').agg(['mean', 'median', 'std']).columns
# MultiIndex([( 'invoiceno',   'mean'),
#             ( 'invoiceno', 'median'),
#             ( 'invoiceno',    'std'),
#             (  'quantity',   'mean'),
#             (  'quantity', 'median'),
#             (  'quantity',    'std'),
#             ( 'unitprice',   'mean'),
#             ( 'unitprice', 'median'),
#             ( 'unitprice',    'std'),
#             (   'revenue',   'mean'),
#             (   'revenue', 'median'),
#             (   'revenue',    'std'),
#             ('customerid',   'mean'),
#             ('customerid', 'median'),
#             ('customerid',    'std'),
#             (   'null_id',   'mean'),
#             (   'null_id', 'median'),
#             (   'null_id',    'std')],
#            )

# %%
df.groupby(['country', 'unitprice']).agg('max').head()
# Out:
# /var/folders/fv/zc4lh9sn7bnf55fy6jhl0k900000gn/T/ipykernel_63458/2401352451.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['country', 'unitprice']).agg('max').head()
#                      invoiceno         invoicedate  \
# country   unitprice
# Australia 0.19          578459 2011-11-24 12:30:00
#           0.25          545475 2011-03-03 10:59:00
#           0.29          559919 2011-07-13 15:30:00
#           0.34          563614 2011-08-18 08:51:00
#           0.36          569650 2011-10-05 12:44:00
#
#                                           description  quantity  revenue  \
# country   unitprice
# Australia 0.19          STAR DECORATION PAINTED ZINC         96    45.60
#           0.25           PACK OF 12 WOODLAND TISSUES        -80   108.00
#           0.29       FRENCH STYLE STORAGE JAR BONBONS        48    69.60
#           0.34                       WRAP WEDDING DAY       -56   136.00
#           0.36                VINTAGE KID DOLLY CARD        120   103.68
#
#                      customerid   null_id
# country   unitprice
# Australia 0.19            12415       NaN
#           0.25            12415  170927.0
#           0.29            12415  320717.0
#           0.34            12415  373541.0
#           0.36            12415  388229.0

# %%
str_lst=['a', 'b', 'v', 'z', 't', 'e', '0', 'ei', '!', 'B', ' Yo']

sorted(str_lst)
# Out:
# [' Yo', '!', '0', 'B', 'a', 'b', 'e', 'ei', 't', 'v', 'z']

# %% [markdown]
# ### Pivot table

# %%
student=pd.read_csv('../data/student-por.csv', sep=';')

student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
student.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
student.pivot_table(index=['school'], columns=['sex'])
# Out:
#             Dalc                Fedu                   G1             \
# sex            F         M         F         M          F          M
# school
# GP      1.291139  1.698925  2.396624  2.575269  12.286920  11.602151
# MS      1.273973  2.087500  1.958904  2.050000  10.582192   9.787500
#
#                G2                    G3             ...  freetime            \
# sex             F          M          F          M  ...         F         M
# school                                              ...
# GP      12.502110  11.688172  13.004219  12.032258  ...  2.953586  3.408602
# MS      10.719178  10.087500  11.034247   9.950000  ...  3.212329  3.262500
#
#            goout              health           studytime           traveltime  \
# sex            F         M         F         M         F         M          F
# school
# GP      3.109705  3.193548  3.464135  3.768817  2.189873  1.790323   1.405063
# MS      3.157534  3.437500  3.212329  3.800000  1.883562  1.575000   1.767123
#
#
# sex            M
# school
# GP      1.462366
# MS      1.937500
#
# [2 rows x 32 columns]

# %%
student.pivot_table(index=['school'], columns=['sex'], aggfunc='max')
# Out:
#        Dalc    Fedu        Fjob           G1      G2      ...      reason  \
# sex       F  M    F  M        F        M   F   M   F   M  ...           F
# school                                                    ...
# GP        5  5    4  4  teacher  teacher  18  18  19  18  ...  reputation
# MS        4  5    4  4  teacher  teacher  19  17  18  18  ...  reputation
#
#                    romantic      schoolsup      studytime    traveltime
# sex              M        F    M         F    M         F  M          F  M
# school
# GP      reputation      yes  yes       yes  yes         4  4          4  4
# MS      reputation      yes  yes       yes  yes         4  4          4  4
#
# [2 rows x 62 columns]

# %%
student.pivot_table(aggfunc='mean', index=['school'], columns=['sex'], values=['G3'])
# Out:
#                G3
# sex             F          M
# school
# GP      13.004219  12.032258
# MS      11.034247   9.950000

# %% [markdown]
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)[source]¶

# %%
student.pivot_table(aggfunc='mean', index=['school'], columns=['sex', 'studytime'], values=['G3', 'Dalc'])
# Out:
#                Dalc                                                    \
# sex               F                                       M
# studytime         1         2         3         4         1         2
# school
# GP         1.428571  1.248000  1.358491  1.058824  1.818182  1.703704
# MS         1.340426  1.260274  1.136364  1.500000  2.282609  1.653846
#
#                                   G3                                   \
# sex                                F
# studytime         3     4          1          2          3          4
# school
# GP         1.166667  1.70  12.142857  12.904000  13.528302  14.235294
# MS         1.500000  3.25  10.340426  10.986301  12.136364  14.000000
#
#
# sex                M
# studytime          1          2          3      4
# school
# GP         11.194805  12.469136  13.666667  12.00
# MS          9.586957  10.115385  13.250000   9.75

# %%
student.studytime.unique()
# Out:
# array([2, 3, 1, 4])

# %%
#help(student.pivot_table)

# %% [markdown]
# ### Cross table

# %% [markdown]
# ### Aplicación de funciones

# %% [markdown]
# ### Json Normalize, Explode

# %% [markdown]
# ### Unión de dataframes

# %% [markdown]
# ### Eval y query

# %% [markdown]
# ### lookup

# %% [markdown]
# ### get

# %% [markdown]
# ### index y reindex

# %% [markdown]
# ### Multi index

# %% [markdown]
# ### Exportar datos

# %% [markdown]
# ### Métodos habituales de pandas

# %% [markdown]
# ```python
# df.head()                     # printea la cabeza, por defecto 5 filas
# df.tail()                     # pritea la cola, por defecto 5 filas
# df.describe()                 # descripcion estadistica
# df.info()                     # informacion del df
# df.info(memory_usage='deep')
# df.columns                    # muestra columna
# df.index                      # muestra indice
# df.dtypes                     # muestra tipos de datos de las columnas
# df.plot()                     # hace un grafico
# df.hist()                     # hace un histograma
# df.col.value_counts()         # cuenta los valores unicos de una columna
# df.col.unique()               # muestra valores unicos de una columna
# df.copy()                     # copia el df
# df.drop()                     # elimina columnas o filas (axis=0,1)
# df.dropna()                   # elimina nulos
# df.fillna()                   # rellena nulos
# df.shape                      # dimensiones del df
# df._get_numeric_data()        # selecciona columnas numericas
# df.rename()                   # renombre columnas
# df.str.replace()              # reemplaza columnas de strings
# df.astype(dtype='float32')    # cambia el tipo de dato
# df.iloc[]                     # localiza por indice
# df.loc[]                      # localiza por elemento
# df.transpose()                # transpone el df
# df.T
# df.sample(n, frac)            # muestra del df
# df.col.sum()                  # suma de una columna
# df.col.max()                  # maximo de una columna
# df.col.min()                  # minimo de una columna
# df[col]                       # selecciona columna
# df.col
# df.isnull()                   # valores nulos
# df.isna()
# df.notna()                    # valores no nulos
# df.drop_duplicates()          # eliminar duplicados
# df.reset_index(inplace=True)  # resetea el indice y sobreescribe
# ```
