# %%
import pandas as pd

# %%
df=pd.read_csv('../data/Marketing-Customer-Analysis.csv')

df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# **listas comprimidas**

# %%
['a' if i%2 else 'b' for i in range(10)]
# Out:
# ['b', 'a', 'b', 'a', 'b', 'a', 'b', 'a', 'b', 'a']

# %% [markdown]
# **apply**  Apply es map

# %%
df.Income.apply(lambda x: x/1000)
# Out:
# 0       56.274
# 1        0.000
# 2       48.767
# 3        0.000
# 4       43.836
#          ...
# 9129    71.941
# 9130    21.604
# 9131     0.000
# 9132    21.941
# 9133     0.000
# Name: Income, Length: 9134, dtype: float64

# %%
def funcion(x):
    
    return 2*x/100
    
df['income_2']=df.Income.apply(funcion)

df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                         0                  1  Corporate Auto  Corporate L3
# ...

# %%
df[['Income', 'income_2']].apply(lambda x: sum(x))
# Out:
# Income      3.439625e+08
# income_2    6.879250e+06
# dtype: float64

# %%
df.apply(lambda x: 2*x).head()
# Out:
#          Customer                 State  Customer Lifetime Value Response  \
# 0  BU79786BU79786  WashingtonWashington              5527.038558     NoNo
# 1  QZ44356QZ44356        ArizonaArizona             13959.071806     NoNo
# 2  AI49188AI49188          NevadaNevada             25774.863300     NoNo
# 3  WW63253WW63253  CaliforniaCalifornia             15291.723654     NoNo
# 4  HB64268HB64268  WashingtonWashington              5627.385150     NoNo
#
#            Coverage         Education Effective To Date      EmploymentStatus  \
# 0        BasicBasic  BachelorBachelor    2/24/112/24/11      EmployedEmployed
# 1  ExtendedExtended  BachelorBachelor    1/31/111/31/11  UnemployedUnemployed
# 2    PremiumPremium  BachelorBachelor    2/19/112/19/11      EmployedEmployed
# 3        BasicBasic  BachelorBachelor    1/20/111/20/11  UnemployedUnemployed
# 4        BasicBasic  BachelorBachelor      2/3/112/3/11      EmployedEmployed
#
# ...

# %% [markdown]
# **group by**

# %%
df.groupby('State').sum().reset_index()
# Out:
#         State  Customer Lifetime Value     Income  Monthly Premium Auto  \
# 0     Arizona             1.338786e+07   63701400                156480
# 1  California             2.521149e+07  118310682                294510
# 2      Nevada             7.106015e+06   33841992                 83154
# 3      Oregon             2.101062e+07   97686494                243880
# 4  Washington             6.401135e+06   30421941                 73441
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                    25711                          81372
# 1                    47510                         150094
# 2                    13524                          42804
# 3                    38732                         125467
# 4                    12419                          39285
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount  \
# 0                        653                5224        7.243905e+05
# ...

# %% [markdown]
# **map**

# %%
lst=[1,2,3,4]


list(map(lambda x: x**2, lst))
# Out:
# [1, 4, 9, 16]

# %%
lst=[(1,2), (3,4)]


list(map(lambda x, y: x**2+y, *lst))
# Out:
# [4, 8]

# %%
lst=[(1,2), (3,4)]


list(map(lambda x: x[0]**2+x[1], lst))
# Out:
# [3, 13]

# %% [markdown]
# **pivot table**

# %%
import numpy as np

pd.pivot_table(df, values='Income', index='State',
                    columns='Coverage', aggfunc=np.sum)
# Out:
# Coverage       Basic  Extended   Premium
# State
# Arizona     39513451  18669180   5518769
# California  72241106  35001002  11068574
# Nevada      19948204  10392736   3501052
# Oregon      61070604  27532886   9083004
# Washington  19622643   8158430   2640868

# %%
df[['State', 'Coverage', 'Income']].groupby(['State', 'Coverage']).sum().apply(round).head()
# Out:
#                        Income
# State      Coverage
# Arizona    Basic     39513451
#            Extended  18669180
#            Premium    5518769
# California Basic     72241106
#            Extended  35001002

# %%
round(2.45)
# Out:
# 2

# %%
df['income_2'].apply(round)
# Out:
# 0       1125
# 1          0
# 2        975
# 3          0
# 4        877
#         ...
# 9129    1439
# 9130     432
# 9131       0
# 9132     439
# 9133       0
# Name: income_2, Length: 9134, dtype: int64

# %%
df[['State', 'Coverage', 'Income']].groupby(['State', 'Coverage']).sum().loc[[('Arizona','Basic')]]
# Out:
#                     Income
# State   Coverage
# Arizona Basic     39513451

# %% [markdown]
# **regex**

# %%
import re

# %%
st='oleqjngeoki2 vr22 676ñ,m dfñbkl'

# %%
patron=r'vr\d+'

raw=re.findall(patron, st)[0]

# %%
patron='[0-9]+'

# %%
int(re.findall(patron, raw)[0])
# Out:
# 22

# %%
df['income_2']=df.income_2.apply(str)

df['chorras']='vr'+df.income_2+df.State

df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ... Number of Policies  \
# 0           2/24/11         Employed      F   56274  ...                  1
# 1           1/31/11       Unemployed      F       0  ...                  8
# 2           2/19/11         Employed      F   48767  ...                  2
# 3           1/20/11       Unemployed      M       0  ...                  7
# 4            2/3/11         Employed      M   43836  ...                  1
#
# ...

# %%
def funcion_regex(x):
    
    patron=r'vr\d+'

    raw=re.findall(patron, x)[0]

    patron='[0-9]+'
    
    return float(re.findall(patron, raw)[0])

# %%
df.chorras.apply(funcion_regex).head()
# Out:
# 0    1125.0
# 1       0.0
# 2     975.0
# 3       0.0
# 4     876.0
# Name: chorras, dtype: float64

# %% [markdown]
# **init**

# %%
class Aqui():
    
    def extract(self, x):
        
        return x**2

# %%
Aqui().extract(8)
# Out:
# 64

# %%
Aqui(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 Aqui(8)
#
# TypeError: Aqui() takes no arguments

# %%
class Alli():
    
    def __init__(self, a):
        self.a=a
    
    def extract(self, x):
        
        return x**2

# %%
Alli().extract(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 Alli().extract(8)
#
# TypeError: __init__() missing 1 required positional argument: 'a'

# %%
Alli(1).extract(8)
# Out:
# 64

# %%
class Aculla():
    
    a='aaaaaaaaaaaa'
    
    def extract(self, x):
        
        return x**2

# %%
Aculla().a
# Out:
# 'aaaaaaaaaaaa'
