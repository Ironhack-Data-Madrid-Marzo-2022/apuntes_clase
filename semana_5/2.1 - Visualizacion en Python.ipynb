# %% [markdown]
# # 2.1 - Visualización en Python

# %% [markdown]
# En Python podemos realizar visualizaciones de todo tipo. En esta clase veremos algunas herramientas que nos permitirán crear gráficos. Algunos ejemplos:
#
#
# ![cuadrados](images/cuadrados.png)
#
#
# ![julia](images/julia.png)
#
#
# ![mandelbrot](images/mandelbrot.png)
#
# $$$$
#
# Esto no es nuestro objetivo.
#
# En realidad, nuestros objetivos son dos, en primer lugar visualizar los datos para realizar un análisis exploratorio de los datos, EDA por las siglas en inglés. Necesitamos describir correctamente los datos y la visualización es una gran herramienta para ello. Nuestro segundo objetivo es representar los datos de tal manera que tengan narrativa, que podamos contar una historia a través de ellos. Es lo que se llama storytelling.
#
# **¿Qué es storytelling?**
#
# Es una técnica que utiliza datos para contar una historia. Es una forma útil de presentar información, lo que significa que se puede utilizar tanto con audiencias internas como externas. Si estás realizando la presentación de un informe, por ejemplo, puedes expresar mejor una idea o explicar mejor un punto si utilizas gráficos, tablas o infografías, ya que dichos contenidos retienen la atención de tu audiencia de una manera que un texto o incluso un video no lo pueden hacer. Estas herramientas facilitan el procesamiento de toda la información a la vez y la toma de decisiones.
#
# El storytelling va más allá de representar datos de una manera más atractiva. Consiste en mostrar cómo o por qué los datos cambiaron durante un período, y para eso es necesario reunir:
#
# + una narrativa
# + un contexto
# + personajes
#
# Estos son los factores clave para que tu audiencia se involucre realmente con el contenido.
#
# $$$$
#
# Comenzaremos repasando algunos gráficos de la clase anterior, para EDA.
#
# **Matplotlib/Pylab - Seaborn**

# %%
import pylab as plt
# import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(15, 8)  # tamaño de los graficos por defecto

import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../data/video_games_sales.csv')

df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# Comenzamos con la descripción estadística de los datos:

# %%
df.describe().T
# Out:
#                    count         mean         std      min      25%      50%  \
# Year_of_Release  16450.0  2006.487356    5.878995  1980.00  2003.00  2007.00
# NA_Sales         16719.0     0.263330    0.813514     0.00     0.00     0.08
# EU_Sales         16719.0     0.145025    0.503283     0.00     0.00     0.02
# JP_Sales         16719.0     0.077602    0.308818     0.00     0.00     0.00
# Other_Sales      16719.0     0.047332    0.186710     0.00     0.00     0.01
# Global_Sales     16719.0     0.533543    1.547935     0.01     0.06     0.17
# Critic_Score      8137.0    68.967679   13.938165    13.00    60.00    71.00
# Critic_Count      8137.0    26.360821   18.980495     3.00    12.00    21.00
# User_Count        7590.0   162.229908  561.282326     4.00    10.00    24.00
#
#                      75%       max
# Year_of_Release  2010.00   2020.00
# NA_Sales            0.24     41.36
# EU_Sales            0.11     28.96
# JP_Sales            0.04     10.22
# Other_Sales         0.03     10.57
# Global_Sales        0.47     82.53
# Critic_Score       79.00     98.00
# Critic_Count       36.00    113.00
# User_Count         81.00  10665.00

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 8.0 MB

# %% [markdown]
# **Count plot**

# %%
sns.countplot(x=df.Genre, palette='Blues')

plt.xticks(rotation=35);

# %%
sns.countplot(x=df[df.Genre=='Action'].Genre, 
              hue=df.Platform,
              palette='gist_rainbow')

plt.xticks(rotation=35);

# %% [markdown]
# **Histograma**

# %%
sns.histplot(x=df.Year_of_Release);

# %%
df.Year_of_Release.min(), df.Year_of_Release.max()
# Out:
# (1980.0, 2020.0)

# %%
sns.histplot(x=df.Year_of_Release, bins=40);

# %%
sns.histplot(x=df.Year_of_Release, binwidth=5);

# %%
sns.histplot(x=df.Year_of_Release, 
             bins=40,
             kde=True  # kernel density estimation, curva de la distribucion
            );

# %%
sns.histplot(x=df.Year_of_Release, 
             bins=40,
             element='step'  # contorno de las barras
            );

# %%
sns.histplot(x=df.Year_of_Release, 
             bins=40,
             element='step',  # contorno de las barras
             fill=False      # relleno
            );

# %%
sns.histplot(x=df.Year_of_Release, 
             bins=40,
             element='step',  # contorno de las barras
             cumulative=True
            );

# %%
sns.histplot(x=df.Year_of_Release, 
             hue=df[(df.Genre=='Racing') | (df.Genre=='Action')].Genre,
             bins=40,
             element='step',  # contorno de las barras
             multiple='fill'   # normaliza, entre 0 y 1
            );

# %%
sns.histplot(x=df.Year_of_Release, 
             hue=df[(df.Genre=='Racing') | (df.Genre=='Action')].Genre,
             bins=40, 
             element='step', 
             fill=False);

# %% [markdown]
# **Scatter Plot**

# %%
sns.scatterplot(data=df, x='Genre', y='EU_Sales');

# %%
df.groupby('Year_of_Release').count().Name.plot();

# %%
sns.scatterplot(data=df[df.Publisher=='Nintendo'], 
                hue='Genre',
                x='JP_Sales', 
                y='Global_Sales',
               );

# %% [markdown]
# **Pie Chart**

# %%
df=df.dropna()

tab=pd.crosstab(df.Rating, df.Genre)

tab
# Out:
# Genre   Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Rating
# AO           1          0         0     0         0       0       0
# E          191         49         6   163       240      89     350
# E10+       299         32        14    80       104      24      79
# K-A          0          0         0     1         0       0       0
# M          557         85        45    11         3       0      17
# RP           0          0         0     0         0       0       0
# T          582         82       313   129        56       5     135
#
# Genre   Role-Playing  Shooter  Simulation  Sports  Strategy
# Rating
# AO                 0        0           0       0         0
# E                 73       22         103     754        42
# E10+             100       34          28      74        62
# K-A                0        0           0       0         0
# M                152      523           5      11        24
# RP                 0        0           0       0         1
# T                387      285         161     104       138

# %%
fig, ax = plt.subplots(1, 3)  # alegre, 1 fila 3 columnas, es decir 3 plots

for i,cat in enumerate(tab.index[:3]):
    tab.loc[cat].plot.pie(ax=ax[i], autopct='%1.f%%', startangle=90)
    
    ax[i].set_ylabel('')
    ax[i].set_xlabel(cat, fontweight='bold')

# %% [markdown]
# **Boxplot**

# %%
sns.boxplot(data=df.User_Score);

# %% [markdown]
# **Violin Plot**

# %%
sns.violinplot(data=df.User_Score);

# %% [markdown]
# **Correlacion**

# %%
corr=df.corr(method='pearson')

# %%
corr
# Out:
#                  Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year_of_Release         1.000000 -0.016239  0.041346 -0.038443     0.042315
# NA_Sales               -0.016239  1.000000  0.841808  0.468607     0.726757
# EU_Sales                0.041346  0.841808  1.000000  0.519929     0.716330
# JP_Sales               -0.038443  0.468607  0.519929  1.000000     0.394823
# Other_Sales             0.042315  0.726757  0.716330  0.394823     1.000000
# Global_Sales            0.006661  0.955793  0.939313  0.613546     0.804028
# Critic_Score           -0.007661  0.233580  0.213102  0.147314     0.191509
# Critic_Count            0.203336  0.283917  0.265740  0.168299     0.239513
# User_Count              0.199348  0.246208  0.283504  0.072773     0.240085
#
#                  Global_Sales  Critic_Score  Critic_Count  User_Count
# Year_of_Release      0.006661     -0.007661      0.203336    0.199348
# NA_Sales             0.955793      0.233580      0.283917    0.246208
# EU_Sales             0.939313      0.213102      0.265740    0.283504
# JP_Sales             0.613546      0.147314      0.168299    0.072773
# Other_Sales          0.804028      0.191509      0.239513    0.240085
# Global_Sales         1.000000      0.237556      0.290397    0.264151
# Critic_Score         0.237556      1.000000      0.396478    0.265639
# Critic_Count         0.290397      0.396478      1.000000    0.365603
# User_Count           0.264151      0.265639      0.365603    1.000000

# %%
sns.set(style='white')   # estilo blanco


mascara=np.triu(np.ones_like(corr, dtype=bool))    # genera una mascara para la triangular superior


cmap=sns.diverging_palette(0, 10, as_cmap=True)    # paleta de colores

sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            center=0,
            square=True,
            linewidths=0.5,
            cbar_kws={'shrink':0.5}
           );

# %% [markdown]
# **Radar chart**

# %%
data=df.groupby('Genre').count().T.iloc[0]

etiquetas=list(df.Genre.unique())

# %%
angulos=np.linspace(0, 2*np.pi, len(etiquetas), endpoint=False)

data=np.concatenate((data, [data[0]]))
angulos=np.concatenate((angulos, [angulos[0]]))

# %%
fig=plt.figure()

ax=fig.add_subplot(111, polar=True)

ax.plot(angulos, data, 'o-', linewidth=2)
ax.fill(angulos, data, alpha=0.25)
ax.set_xticklabels([])
ax.set_thetagrids(angulos * 180/np.pi, etiquetas+['Sports'])
ax.set_title('Count by Genre')
ax.grid(True);

# %% [markdown]
# **Gráficos en 3D**

# %%
from mpl_toolkits.mplot3d import Axes3D

# voy a pintar una helice


ang=np.linspace(-5*np.pi, 5*np.pi, 200)

x=3 * np.cos(ang)
y=3 * np.sin(ang)

z=np.linspace(-4, 4, 200)

fig=plt.figure()
ax=fig.gca(projection='3d')
ax.plot(x, y, z);
# Out:
# /var/folders/fv/zc4lh9sn7bnf55fy6jhl0k900000gn/T/ipykernel_30612/1493586207.py:14: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax=fig.gca(projection='3d')

# %%
ang=np.linspace(-5*np.pi, 5*np.pi, 200)

z=np.linspace(-4, 4, 200)

r=2*z+1

x=r * np.cos(ang)
y=r * np.sin(ang)



fig=plt.figure()
ax=fig.gca(projection='3d')
ax.plot(x, y, z);
# Out:
# /var/folders/fv/zc4lh9sn7bnf55fy6jhl0k900000gn/T/ipykernel_30612/2236947430.py:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax=fig.gca(projection='3d')

# %% [markdown]
# **Line chart**
#
# Normalmente para ver evolutivos.

# %%
df=df.groupby('Year_of_Release').sum()

df.head()
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# Year_of_Release
# 1985.0               0.00      0.03      0.00         0.01          0.03
# 1988.0               0.00      0.02      0.00         0.01          0.03
# 1992.0               0.02      0.00      0.00         0.00          0.03
# 1994.0               0.39      0.26      0.53         0.08          1.27
# 1996.0               7.91      6.88      4.06         1.24         20.10
#
#                  Critic_Score  Critic_Count  User_Count
# Year_of_Release
# 1985.0                   59.0           9.0        19.0
# 1988.0                   64.0          75.0      4572.0
# 1992.0                   85.0          44.0      1796.0
# 1994.0                   69.0           4.0         4.0
# 1996.0                  626.0          83.0      4970.0

# %%
plt.plot(df)
plt.legend(df.columns);

# %% [markdown]
# **Bar chart race**
#
# https://pypi.org/project/bar-chart-race/

# %%
# !pip install bar-chart-race
# Out:
# Collecting bar-chart-race
#   Using cached bar_chart_race-0.1.0-py3-none-any.whl (156 kB)
# Requirement already satisfied: matplotlib>=3.1 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from bar-chart-race) (3.5.1)
# Requirement already satisfied: pandas>=0.24 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from bar-chart-race) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (21.3)
# Requirement already satisfied: numpy>=1.17 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (4.30.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from matplotlib>=3.1->bar-chart-race) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from pandas>=0.24->bar-chart-race) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/iudh/miniforge3/envs/tensor/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->bar-chart-race) (1.15.0)
# Installing collected packages: bar-chart-race
# Successfully installed bar-chart-race-0.1.0

# %%
import warnings
warnings.filterwarnings('ignore')

import bar_chart_race as bcr

df=bcr.load_dataset('covid19_tutorial')

display(df)

bcr.bar_chart_race(df=df, filename='images/covid19.mp4')
bcr.bar_chart_race(df=df)
# Out:
#             Belgium  China  France  Germany  Iran  Italy  Netherlands  Spain  \
# date
# 2020-04-03     1143   3326    6520     1275  3294  14681         1490  11198
# 2020-04-04     1283   3330    7574     1444  3452  15362         1656  11947
# 2020-04-05     1447   3333    8093     1584  3603  15887         1771  12641
# 2020-04-06     1632   3335    8926     1810  3739  16523         1874  13341
# 2020-04-07     2035   3335   10343     2016  3872  17127         2108  14045
# 2020-04-08     2240   3337   10887     2349  3993  17669         2255  14792
# 2020-04-09     2523   3339   12228     2607  4110  18279         2403  15447
# 2020-04-10     3019   3340   13215     2767  4232  18849         2520  16081
# 2020-04-11     3346   3343   13851     2894  4357  19468         2653  16606
# 2020-04-12     3600   3343   14412     3022  4474  19899         2747  17209
#
#               USA  United Kingdom
# date
# 2020-04-03   7418            3611
# 2020-04-04   8387            4320
# 2020-04-05   9489            4943
# 2020-04-06  10783            5385
# 2020-04-07  12798            6171
# 2020-04-08  14704            7111
# 2020-04-09  16553            7993
# 2020-04-10  18595            8974
# 2020-04-11  20471            9892
# 2020-04-12  22032           10629
# <video width="952" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
